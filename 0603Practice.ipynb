# %%
import torch
from torch.autograd import Variable

# %%
a = torch.ones(2,2)
print(a)
# Out:
#  1  1
#  1  1
# [torch.FloatTensor of size 2x2]

# %%
a = Variable(a,requires_grad=True)
print(a)
# Out:
# Variable containing:
#  1  1
#  1  1
# [torch.FloatTensor of size 2x2]

# %%
print(a.data)
print(a.grad)
print(a.grad_fn)
# Out:
#  1  1
#  1  1
# [torch.FloatTensor of size 2x2]
#
# None
# None
