# %%
import http.server
import ssl
import torch

# %%
torch.cuda.current_device()
torch.cuda.device_count()
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-3-8924fa518869> in <module>()
# ----> 1 torch.cuda.current_device()
#       2 torch.cuda.device_count()
#
# ~\Anaconda3\envs\tc\lib\site-packages\torch\cuda\__init__.py in current_device()
#     324 def current_device():
#     325     """Returns the index of a currently selected device."""
# --> 326     _lazy_init()
#     327     return torch._C._cuda_getDevice()
#     328
#
# ~\Anaconda3\envs\tc\lib\site-packages\torch\cuda\__init__.py in _lazy_init()
#     158         raise RuntimeError(
#     159             "Cannot re-initialize CUDA in forked subprocess. " + msg)
# --> 160     _check_driver()
#     161     torch._C._cuda_init()
#     162     torch._C._cuda_sparse_init()
#
# ~\Anaconda3\envs\tc\lib\site-packages\torch\cuda\__init__.py in _check_driver()
#      72 def _check_driver():
# ...
