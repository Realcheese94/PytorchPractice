# %%
import torch as tc
import numpy as np

# %%
#텐서 생성
x1 = tc.Tensor(3)
x2 = tc.Tensor(3,3)
#일반적 텐서 생성 방법
num1 = torch.rand(3,3)

# %%
#tensor 에서 numpy로 , numpy에서 tensor로
a = tc.rand(3,3)
b = a.numpy()

a1 = np.array([1,2,3,4])
b1 = tc.Tensor(a1)

# %%
#텐서의 형변환 과정
a = tc.rand(3,3)
a = a.view(1,1,3,3)
a
# Out:
# (0 ,0 ,.,.) =
#   0.5196  0.1113  0.4860
#   0.9503  0.0573  0.4292
#   0.2598  0.8583  0.3986
# [torch.FloatTensor of size 1x1x3x3]

# %%
#텐서를 합치는 경우
a= tc.randn(1,1,3,3)
b= tc.randn(1,1,3,3)
c = tc.cat((a,b),0)

# %%
#파이토치 randn이 정규분포 0을 따르는지...
x = tc.randn(2,3)

x1 = tc.randperm(101)
print(x1)
x1 =tc.zeros(2,3)
x1 = tc.ones(2,3)
print(x1)
# Out:
#   97
#   42
#   51
#   14
#   18
#   22
#   52
#   12
#   73
#   27
#   13
#   68
#   62
#   37
#   64
#   54
#    4
#   36
#   45
#   75
#   26
#   47
#   84
#   82
#   88
#   35
#   65
#   69
#   56
#   30
#    8
#   53
#    9
#   32
#   24
#   40
#   48
#   96
#   16
#   49
#   57
#   39
#   70
#    3
#   92
#   79
#   61
#   44
#   89
#   50
#   81
#   34
#   95
#   58
#   29
#   78
#   23
#   60
#   91
#   83
#   85
#   11
#    5
#   33
#   28
#   77
#   31
#   55
#    7
#   87
#   20
#   59
#   72
#    1
#   94
#   41
#  100
#   63
#    2
#   67
#   46
#   66
#   76
#   25
#   10
#   15
#   80
#    6
#   90
#   21
#   98
#   38
#   19
#   99
#   93
#   86
#   74
#   43
#   71
#    0
#   17
# [torch.LongTensor of size 101]
#
#
#  1  1  1
#  1  1  1
# [torch.FloatTensor of size 2x3]

# %%
#토치 arrange
num1 = tc.arange(0,10,step=2)
num1
num2 = tc.linspace(0,10,7)
num2
# Out:
#   0.0000
#   1.6667
#   3.3333
#   5.0000
#   6.6667
#   8.3333
#  10.0000
# [torch.FloatTensor of size 7]
