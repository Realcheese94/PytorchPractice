# %%
import torch

# %%
inp = torch.randn(6,3,224,224).cuda()
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-5-99a996044494> in <module>()
# ----> 1 inp = torch.randn(6,3,224,224).cuda()
#
# ~\Anaconda3\envs\tc\lib\site-packages\torch\_utils.py in _cuda(self, device, async)
#      67         else:
#      68             new_type = getattr(torch.cuda, self.__class__.__name__)
# ---> 69             return new_type(self.size()).copy_(self, async)
#      70
#      71
#
# ~\Anaconda3\envs\tc\lib\site-packages\torch\cuda\__init__.py in _lazy_new(cls, *args, **kwargs)
#     401 @staticmethod
#     402 def _lazy_new(cls, *args, **kwargs):
# --> 403     _lazy_init()
#     404     # We need this method only for lazy init, so we can remove it
#     405     del _CudaBase.__new__
#
# ~\Anaconda3\envs\tc\lib\site-packages\torch\cuda\__init__.py in _lazy_init()
#     158         raise RuntimeError(
# ...
